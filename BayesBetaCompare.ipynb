# %%
import scipy.stats as stats
import scipy.integrate as integrate
import numpy as np
import pandas as pd
import plotly.express as px
from BayesBetaCompare import CompareReview

# %%
data=[[4.2/5, 10] ,[3/5, 18], [4.0/5, 14]]
res=CompareReview(data, lev=0.9, nExperiments=100000)
res.ContingencyT
# Out:
#       Data0   Data1   Data2
# Data0   ---  45.17%  83.07%
# Data1   ---     ---  99.01%
# Data2   ---     ---     ---

# %%
res.figs[2]
