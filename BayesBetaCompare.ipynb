# %%
import scipy.stats as stats
import scipy.integrate as integrate
import numpy as np
import pandas as pd
import plotly.express as px
from BayesBetaCompare import CompareReview

# %%
data=[[4.3/5, 5321] ,[4.4/5, 4109], [4.5/5, 5262], [4.4/5, 4874]]
res=CompareReview(data, lev=0.5, nExperiments=100000)
res.ContingencyT
# Out:
#       Data0   Data1   Data2   Data3
# Data0   ---  99.74%  99.95%  99.81%
# Data1   ---     ---  99.85%  49.91%
# Data2   ---     ---     ---   0.06%
# Data3   ---     ---     ---     ---

# %%
res.figs[5]
